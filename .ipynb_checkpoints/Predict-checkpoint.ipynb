# %% [markdown]
# # Predict corona cases

# %%
#!pip install convoys
import convoys
import pandas as pd
import requests
import io
import cloudpickle as cp
from fbprophet import Prophet
import numpy as np
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
max_cases = 25000
periods = 20

# %%
df = pd.read_csv(io.StringIO(requests.get("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv").content.decode('utf-8')))
df = df[df["Country/Region"] == "Switzerland"].T.iloc[4:].reset_index()
df.columns = ["ds", "y"]
df["ds"] = pd.to_datetime(df["ds"],infer_datetime_format=True).dt.date
df["cap"] = max_cases
df = df[df["y"]>0]
df.reset_index(drop=True)
df.head()
# Out:
#             ds   y    cap
# 34  2020-02-25   1  25000
# 35  2020-02-26   1  25000
# 36  2020-02-27   8  25000
# 37  2020-02-28   8  25000
# 38  2020-02-29  18  25000

# %%
m = Prophet(mcmc_samples=50,growth='logistic').fit(df);
future = m.make_future_dataframe(periods=periods,freq='d')
future["cap"] = max_cases #whats the max RW we can reach
forecast = m.predict(future)
forecast = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper',"cap"]]
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:24 of 100 iterations ended with a divergence (24 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
fig1 = m.plot(forecast)

# %%
df['ds'] = df['ds'].astype('datetime64[ns]')
result = pd.merge(df,forecast,on="ds",how="right")[["ds","y","yhat",'yhat_lower', 'yhat_upper',"cap_y"]]

# %%
for index,row in result.iterrows():
    if row.y.isna():
        result.loc[index,"y_merge"] = row
    else:
        result.loc[index,"y_merge"] = row.y

# %%
result
# Out:
#            ds     y          yhat    yhat_lower    yhat_upper  cap_y  y_merge
# 0  2020-02-25     1    -27.663865   -294.662196    225.665787  25000      1.0
# 1  2020-02-26     1   -111.005426   -376.315087    154.557362  25000      1.0
# 2  2020-02-27     8    -73.295538   -355.042319    189.465841  25000      8.0
# 3  2020-02-28     8     67.097772   -204.052238    333.711470  25000      8.0
# 4  2020-02-29    18    120.451227   -170.408113    428.740453  25000     18.0
# 5  2020-03-01    27    203.928501    -61.585701    479.521210  25000     27.0
# 6  2020-03-02    42     76.889156   -193.895176    340.947586  25000     42.0
# 7  2020-03-03    56     45.233610   -202.761693    308.862872  25000     56.0
# 8  2020-03-04    90    -17.328823   -275.170196    262.756713  25000     90.0
# 9  2020-03-05   114     47.068157   -202.390467    326.300066  25000    114.0
# 10 2020-03-06   214    221.624143    -30.569000    483.579043  25000    214.0
# 11 2020-03-07   268    318.804339     51.400183    598.900443  25000    268.0
# 12 2020-03-08   337    458.559360    203.512113    749.775061  25000    337.0
# 13 2020-03-09   374    403.331782    145.719927    686.577196  25000    374.0
# 14 2020-03-10   491    463.478832    191.559270    754.370014  25000    491.0
# 15 2020-03-11   652    517.226296    249.237308    816.643910  25000    652.0
# 16 2020-03-12   652    728.883102    503.422294   1042.796367  25000    652.0
# 17 2020-03-13  1139   1088.739427    840.340462   1390.319932  25000   1139.0
# 18 2020-03-14  1359   1417.571013   1182.447284   1750.907001  25000   1359.0
# 19 2020-03-15  2200   1846.946069   1604.647098   2183.365320  25000   2200.0
# 20 2020-03-16  2200   2148.988346   1908.421436   2480.377157  25000   2200.0
# 21 2020-03-17  2700   2645.025598   2462.975817   3007.294993  25000   2700.0
# 22 2020-03-18  3028   3223.895732   3016.946368   3599.064452  25000   3028.0
# 23 2020-03-19  4075   4057.106101   3849.111861   4446.854762  25000   4075.0
# 24 2020-03-20  5294   5137.668084   4940.364133   5545.471612  25000   5294.0
# 25 2020-03-21  6575   6280.827358   6117.663620   6716.770360  25000   6575.0
# 26 2020-03-22   NaN   7599.544286   7358.046104   8095.443162  25000      NaN
# 27 2020-03-23   NaN   8837.351619   8538.015501   9396.306817  25000      NaN
# 28 2020-03-24   NaN  10271.635259   9946.323481  10914.902019  25000      NaN
# 29 2020-03-25   NaN  11735.919352  11356.760926  12503.177416  25000      NaN
# 30 2020-03-26   NaN  13339.856815  12925.317765  14124.624200  25000      NaN
# 31 2020-03-27   NaN  15015.648808  14523.366655  15827.819954  25000      NaN
# 32 2020-03-28   NaN  16527.501397  16061.610216  17335.805228  25000      NaN
# 33 2020-03-29   NaN  17955.099293  17396.630719  18777.940540  25000      NaN
# 34 2020-03-30   NaN  19031.916222  18441.389250  19825.851154  25000      NaN
# 35 2020-03-31   NaN  20050.174321  19502.629981  20789.005352  25000      NaN
# 36 2020-04-01   NaN  20880.657994  20310.617896  21557.510360  25000      NaN
# 37 2020-04-02   NaN  21686.637435  21132.330632  22291.023992  25000      NaN
# 38 2020-04-03   NaN  22462.000110  21943.079277  23011.107146  25000      NaN
# 39 2020-04-04   NaN  23032.064498  22607.817566  23520.409606  25000      NaN
# 40 2020-04-05   NaN  23529.873884  23113.139850  23979.618335  25000      NaN
# 41 2020-04-06   NaN  23729.998914  23333.648737  24113.895077  25000      NaN
# 42 2020-04-07   NaN  23951.960709  23630.010005  24293.040081  25000      NaN
# 43 2020-04-08   NaN  24080.966474  23725.613314  24423.189926  25000      NaN
# 44 2020-04-09   NaN  24284.267496  23960.370139  24605.412944  25000      NaN
# 45 2020-04-10   NaN  24552.278213  24248.661443  24856.140359  25000      NaN

# %%
#pd.DataFrame([forecast["ds"],forecast["yhat"].diff()])#.plot()
tmp = forecast["ds"].to_frame().join(forecast["yhat"].diff())#.plot()
tmp.index = tmp["ds"]
tmp[["yhat"]].plot()
#tmp.plot()

# %%
#pd.DataFrame([forecast["ds"],forecast["yhat"].diff()])#.plot()
tmp = forecast["ds"].to_frame().join(forecast["yhat"].diff().rolling(2).mean())#.plot()
tmp.index = tmp["ds"]
tmp[["yhat"]].plot()
#tmp.plot()

# %%
forecast["yhat"].diff().rolling(10).sum().plot()
